# %%
a = 10
b = 4
c = a+b
print(c)
# Out:
# 14

# %%
num_1 = 10 # more clear to represent numbers
num_2 = 4
add_1 = num_1 + num_2
print(add_1)
# Out:
# 14

# %%
a = "suhel" # variable a is used but it lacks clarity about what the variable is actually used for.
name = "suhel" # variable 'name' is used and it tells clearly 
               # that is variable stores the value of a certain name.

# %%
name = "suhel"
print(name)
# Out:
# suhel

# %%
my_name = "suhel"
print(my_name)
# Out:
# suhel

# %%
studentone = "tom" # this is hard to understand.
student_one = "tom" # clear to understand.

# %%
my name = "suhel"
print(my name)
# Out:
#   Cell In[8], line 1
#     my name = "suhel"
#        ^
# SyntaxError: invalid syntax

# %%
# Out:
#   Cell In[9], line 1
#     print(a\n)
#             ^
# SyntaxError: unexpected character after line continuation character

# %%
# Out:
#   Cell In[13], line 1
#     a = ("*
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(" hi\n i am student")
# Out:
#  hi
#  i am student

# %%
print("*\n**\n***\n****\n******\n")
# Out:
# *
# **
# ***
# ****
# ******

# %%
print(" hi 
      i am student")
# Out:
#   Cell In[17], line 1
#     print(" hi
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a = 10
print(a)

a = 13
print(a)
# Out:
# 10
# 13

# %%
a = 23
print(a)
A = 13
print(A)
print(a, A)
# Out:
# 23
# 13
# 23 13

# %%
a = 23
print(a, "the value of 'a' is assigned as 23")
A = 13
print(A, " the value of 'A' is assigned as 13")
print(a, A , "as the pytho is case sensitive therefore the value of 'a' was not cahnged")
# Out:
# 23 the value of 'a' is assigned as 23
# 13  the value of 'A' is assigned as 13
# 23 13 as the pytho is case sensitive therefore the value of 'a' was not cahnged

# %%
a = 3 # a is assigned 3
print(a)
b = 5 # b is equal to 5
c a+b # it gives error because it is against the python syntax('=' is not present btw c and a+b)
print(c) # when syntax is wrong, no any instruction will run( see here print(a) is also not execute whereas its synax is correct).
         # in other words, in syntax error no any code will run.
# Out:
#   Cell In[7], line 4
#     c a+b # it gives error because it is against the python syntax('=' is not present btw c and a+b)
#       ^
# SyntaxError: invalid syntax

# %%
a = 0
print(a, "first code")
b = 7
print(b , "second code")
c = a+d     # after here code will not execute. therefore we can say if syntax is correct then usse pehle ka code to execute hoga but wo(here c=a+d)
            # aur uske baad kuch bhi execute nhi hoga.   
print(c)
print(b)
# Out:
# 0 first code
# 7 second code
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       3 b = 7
#       4 print(b , "second code")
# ----> 5 c = a+d     # after here code will not execute. therefore we can say if syntax is correct then usse pehle ka code to execute hoga but wo(here c=a+d)
#       6             # aur uske baad kuch bhi execute nhi hoga.
#       7 print(c)
#
# NameError: name 'd' is not defined

# %%
a1_ = 5
print(a1_)
# Out:
# 5

# %%
a_1 = 5
print(a_1)
# Out:
# 5

# %%
a1 = 5
print(a1)
# Out:
# 5

# %%
1_a = 5
print(1_a)
# Out:
#   Cell In[20], line 1
#     1_a = 5
#      ^
# SyntaxError: invalid decimal literal

# %%
1a = 5
prrint(1a)
# Out:
#   Cell In[21], line 1
#     1a = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
n1_2a = 4
print(n1_2a)
# Out:
# 4

# %%
_1a = 5
print(_1a)
# Out:
# 5

# %%
128 = 9
print(128)
# Out:
#   Cell In[24], line 1
#     128 = 9
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a = 5
a = 10
print(a)
print(a)
# Out:
# 10
# 10

# %%
am i = 5
print(am i)
# Out:
#   Cell In[27], line 1
#     am i = 5
#        ^
# SyntaxError: invalid syntax

# %%
# scores in a test out of 60
hindi_score = 55
english_score = 52
maths_score = 59
sst_score = 50
science_score = 56
computer_science_score = 51
total_subjects = 6
maximum_marks = 360

total_score = hindi_score + english_score + maths_score + sst_score + science_score + computer_science_score 
print(total_score)

avg_score = total_score/ total_subjects
print(avg_score)

percentage = total_score/maximum_marks*100
print(percentage)
# Out:
# 323
# 53.833333333333336
# 89.72222222222223

# %%
# Out:
# 0.8972222222222223

# %% [markdown]
# ### Operators

# %% [markdown]
# #### operators are special symbols in python that perform operations on variables and values. for example, +,-,* etc.
