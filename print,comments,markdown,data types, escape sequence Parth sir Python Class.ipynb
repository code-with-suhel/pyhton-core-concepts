# %%
'''
this
is 
a 
multi-line 
comment
'''
# Out:
# '\nthis\nis \na \nmulti-line \ncomment\n'

# %%
# single line comment

# %% [markdown]
# ghijklmnop

# %%
a = 12
n = 7
# Out:
#   Cell In[13], line 6
#     print("no")                 jjjjjjjjjjjjjjjjjjjjjjjjjjjwifoheqfyw7fyc7yf37t69438789c74r89y8t98t98y89y89ty8 ''''
#                                                                                                                   ^
# SyntaxError: unterminated string literal (detected at line 6)

# %% [markdown]
# # Heading 1
# #### heading 1

# %% [markdown]
# ## heading 2

# %% [markdown]
# ### heading 3

# %% [markdown]
# #### heading 4

# %% [markdown]
# ##### heading 5

# %% [markdown]
# ###### heading 6

# %% [markdown]
# ###### heading 7

# %% [markdown]
# *python* was created by guido van rossum

# %% [markdown]
# python was created by guido van rossum

# %%
# *python*

# %% [markdown]
# **python** was created by guido van rossum

# %% [markdown]
# **python** was created by **guido van rossum**

# %% [markdown]
# ** python ** was created by guido van rossum

# %% [markdown]
# ***python was created by guido van rossum***

# %% [markdown]
# # Data Types

# %%
"hello world" # string
45 # integer
45.6 # float
# Out:
# 45.6

# %%
"45" # string

# %%
True # boolean
False # boolean
# Out:
# False

# %%
"True" # string
# Out:
# 'True'

# %% [markdown]
# # Escape Sequences

# %%
print("python \nData science")
# Out:
# python
# Data science

# %%
print("data\t python\t\t science")
# Out:
# data	 python		 science
